# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('sampleset (Autosaved) (1)excel.xlsx')

# %%
df.head()
# Out:
#          Disease  Age Gender  Vomiting  Nausea  Fever  diarrhea   Chest Pain  \
# 0  heart disease   45   Male         1       1      0          0           1
# 1  heart disease   46   Male         1       1      0          0           1
# 2  heart disease   47   Male         1       1      0          0           1
# 3  heart disease   49   Male         1       1      0          0           1
# 4  heart disease   45   Male         1       1      0          0           1
#
#    Sweating  Tightness of chest            ...              \
# 0         1                   1            ...
# 1         1                   1            ...
# 2         1                   1            ...
# 3         1                   1            ...
# 4         1                   1            ...
#
#    Burning pain in abdoman  Chronic Alcoholic person?  Dry skin   \
# 0                        0                          0          0
# 1                        0                          0          0
# ...

# %% [markdown]
# ## No of Diseases in DataSet

# %%
diseases = list(df['Disease'].unique())
print(diseases)
print()
print("No of Diseases = ",len(diseases))
# Out:
# ['heart disease', 'chronic renal failure ', 'acute appendicitis ', 'renal colic ', 'gynecological disease ', 'urinary tract infection ', 'perforated gastric ulcer ', 'pancreatitis ']
#
# No of Diseases =  8

# %% [markdown]
# ## Age Distribution based on Disease

# %%
plt_list =[]
plt.figure(figsize=(12,10))
for disease in diseases:
    disease_df = df.loc[df['Disease'] == disease]
    sns.distplot(disease_df['Age'], label=disease,bins=5)
    plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Age VS Gender

# %%
sns.boxplot(x='Age', y='Gender', data=df)
plt.show()

# %% [markdown]
# ## Gender Count Based on Disease

# %%
plt_list =[]
for disease in diseases:
    disease_df = df.loc[df['Disease'] == disease]
    sns.countplot(disease_df['Gender'], label = disease);
    plt.legend()
    plt.show()

# %%
plt_list =[]
for disease in diseases:
    print(disease)
    disease_df = df.loc[df['Disease'] == disease]
    sns.boxplot(x='Age', y='Gender', data=disease_df)
    plt.show()
# Out:
# heart disease
# chronic renal failure
# acute appendicitis
# renal colic
# gynecological disease
# urinary tract infection
# perforated gastric ulcer
# pancreatitis

# %%
heart_disease_df = df.loc[df['Disease'] == 'heart disease']

# %%
heart_disease_df.columns
# Out:
# Index(['Disease', 'Age', 'Gender', 'Vomiting', 'Nausea', 'Fever', 'diarrhea ',
#        'Chest Pain', 'Sweating', 'Tightness of chest', 'shortness of breath',
#        'pain of left upper arm (neck, throat, Jaw)', 'back pain',
#        'tachy cardia( Incresed Heart beat)',
#        'brady cardia( Decrased Heart beat)', 'loss of appeite', 'weight loss',
#        'loss of energy', 'nocturnal/poly uria', 'ltching', 'paresthesia',
#        'leg pain', 'pain in bones',
#        'known history of Diabetic or High Blood Pressure ',
#        'Tenderness in stomach +,- ', 'Right sided lower abdoman pain',
#        'Dysuria', 'Incontinance of urine', 'abdominal pain with menstruation',
#        'Delay of menstruation', 'Epigastric pain', 'Burning pain in abdoman',
#        'Chronic Alcoholic person?', 'Dry skin ', 'Red, or dark brown patches ',
#        'Irritation of the patch', 'Scaly skin ',
#        'Burning sensations Itching blisters on skin ', 'Unnamed: 38',
# ...
